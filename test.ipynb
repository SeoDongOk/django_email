# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
custom_header={
  "User-Agent":"PostmanRuntime/7.42.0",
  "Cookie":"GTMVars=b86daa8f8a80f8bb68260b0930f45617; GTMVarsFrom=NET:00:39:02; jobkorea=Site_Oem_Code=C1; sm=keyword=%ec%82%b0%ec%97%85%ea%b8%b0%eb%8a%a5%ec%9a%94%ec%9b%90; ASP.NET_SessionId=ly3vfa5nemwumsm4dzerotbj"
}
url = "https://www.jobkorea.co.kr/Search/?stext=%EC%82%B0%EC%97%85%EA%B8%B0%EB%8A%A5%EC%9A%94%EC%9B%90&local=I000&duty=1000229%2C1000230%2C1000231%2C1000232&tabType=recruit&Page_No=1"

res=requests.get(url,headers=custom_header)
res.encoding = 'utf-8'

url
# Out:
# 'https://www.jobkorea.co.kr/Search/?stext=%EC%82%B0%EC%97%85%EA%B8%B0%EB%8A%A5%EC%9A%94%EC%9B%90&local=I000&duty=1000229%2C1000230%2C1000231%2C1000232&tabType=recruit&Page_No=1'

# %%
soup=BeautifulSoup(res.text,"html.parser")

# %%
import re
import pandas as pd

target = []
base_url = "https://www.jobkorea.co.kr/"

# Assuming soup is already defined and contains parsed HTML
for i in soup.find_all("article", class_="list-item"):
    company = i.find("a", class_="corp-name-link dev-view")
    text = i.find("div", class_="information-title")
    
    if company is None:  # Check if the company element is None
        continue

    company_name = re.sub("\n", "", company.text.strip())
    job_title = re.sub("\n", "", text.text.strip())
    
    target.append({
        "업로드위치": base_url,
        "공고명": job_title,
        "공고회사": company_name,
        "공고주소": base_url + company.attrs["href"]
    })

df = pd.DataFrame(target)

# %%
df
# Out:
#                           업로드위치  \
# 0   https://www.jobkorea.co.kr/
# 1   https://www.jobkorea.co.kr/
# 2   https://www.jobkorea.co.kr/
# 3   https://www.jobkorea.co.kr/
# 4   https://www.jobkorea.co.kr/
# 5   https://www.jobkorea.co.kr/
# 6   https://www.jobkorea.co.kr/
# 7   https://www.jobkorea.co.kr/
# 8   https://www.jobkorea.co.kr/
# 9   https://www.jobkorea.co.kr/
# 10  https://www.jobkorea.co.kr/
# 11  https://www.jobkorea.co.kr/
# 12  https://www.jobkorea.co.kr/
# 13  https://www.jobkorea.co.kr/
# 14  https://www.jobkorea.co.kr/
# 15  https://www.jobkorea.co.kr/
# 16  https://www.jobkorea.co.kr/
# 17  https://www.jobkorea.co.kr/
# 18  https://www.jobkorea.co.kr/
# 19  https://www.jobkorea.co.kr/
#
#                                                   공고명      공고회사  \
# 0   [ESTsoft] 산업기능요원 보충역 (신입)\r                   ...   ㈜이스트소프트
# 1   [산업기능요원 / 보충역] 분야별 개발자 채용 공고\r                ...      ㈜게임엔
# 2                          [리비바이오] 안드로이드개발 산업기능요원 스크랩    ㈜리비바이오
# 3                          [리비바이오] 프론트엔드개발 산업기능요원 스크랩    ㈜리비바이오
# 4   [리비바이오] 백엔드개발 산업기능요원(Node.js)\r               ...    ㈜리비바이오
# 5   [딥브레인 AI] 전문연구요원, 산업기능요원 채용\r                 ...   딥브레인 AI
# 6                         [캐시워크 자회사] 풀스택개발 산업기능요원 스크랩    ㈜더줌코리아
# 7                       [캐시워크 자회사] 프론트엔드개발 산업기능요원 스크랩    ㈜더줌코리아
# 8                         [캐시워크 자회사] 백엔드개발 산업기능요원 스크랩    ㈜더줌코리아
# 9   [smartdoctor] 산업기능요원(병특) 개발자 채용\r             ...    전능아이티㈜
# 10  병역특례(보충역/현역 산업기능요원) 웹/앱 백엔드 및 프런트 프로그래머를 모십니다....     ㈜폴리큐브
# 11                   [캐시워크-병역특례] Flutter개발 산업기능요원 스크랩   넛지헬스케어㈜
# 12                     [캐시워크-병역특례] 프론트엔드개발 산업기능요원 스크랩   넛지헬스케어㈜
# 13  산업기능요원 보충역 (WEB-BE: Java, Spring, Spring Boot ...  ㈜도전하는사람들
# 14  산업기능요원 보충역 (Flutter-Window, Android, iOS, Mac등...  ㈜도전하는사람들
# 15                       [캐시워크-병역특례] 백엔드개발 산업기능요원 스크랩   넛지헬스케어㈜
# 16                       [캐시워크-병역특례] 풀스택개발 산업기능요원 스크랩   넛지헬스케어㈜
# 17                     [캐시워크-병역특례] 안드로이드개발 산업기능요원 스크랩   넛지헬스케어㈜
# 18                       [캐시워크-병역특례] iOS개발 산업기능요원 스크랩   넛지헬스케어㈜
# 19                        [캐시워크-병역특례] QA담당 산업기능요원 스크랩   넛지헬스케어㈜
#
#                                                  공고주소
# 0   https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 1   https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 2   https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 3   https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 4   https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 5   https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 6   https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 7   https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 8   https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 9   https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 10  https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 11  https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 12  https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 13  https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 14  https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 15  https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 16  https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 17  https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 18  https://www.jobkorea.co.kr//Recruit/GI_Read/45...
# 19  https://www.jobkorea.co.kr//Recruit/GI_Read/45...
